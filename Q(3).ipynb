# %%
import skimage.io as io
import numpy as np
import matplotlib.pyplot as plt

# %%
image=io.imread('WIN_20230220_10_14_27_Pro.jpg')

# %%
image.shape
# Out:
# (720, 1280, 3)

# %%
red=image[:,:,0]
green=image[:,:,1]
blue=image[:,:,2]

# %%
plt.imshow(red,cmap="Reds")

# %%
plt.imshow(blue,cmap="Blues")
